# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor

df = pd.read_csv('../content/csv/FINALDATASET_EastSlopesNorth.csv')
df.set_index('Date', inplace=True)

df.drop('Area', axis=1, inplace=True)
df.drop(['Yesterday Danger Above Treeline', 'Yesterday Danger At Treeline', 'Yesterday Danger Below Treeline'], inplace=True, axis=1)
df.drop(['Above Treeline', 'Below Treeline'], inplace=True, axis=1)
df.drop(['Was High Winds 24hr', 'Was Heavy Snowfall 24hr'], axis=1, inplace=True)

df.head()
# Out:
#             At Treeline  Max Air Temp 24hr  Total Snowfall 24hr  \
# Date
# 2022-11-25            1          42.000000            -0.666667
# 2022-11-26            3          30.733333            -0.666667
# 2022-11-27            2          30.533333             0.333333
# 2022-11-28            1          20.766667             6.333333
# 2022-11-29            3          11.466667             0.000000
#
#             Delta SWE 24hr  Min Temp Diff 48hr  Max Windspeed 24hr  \
# Date
# 2022-11-25        0.066667           -1.566667               0.000
# 2022-11-26        0.100000           -0.200000               5.085
# 2022-11-27        0.233333           -6.400000               5.546
# 2022-11-28        0.500000          -15.500000               4.077
# 2022-11-29       -0.100000           -0.266667               6.379
#
#             Max Air Temp 72hr  Total Snowfall 72hr  Weighted Snowfall 96hr  \
# Date
# 2022-11-25           0.000000             0.000000                0.000000
# 2022-11-26           0.000000             0.000000                0.000000
# 2022-11-27          42.000000            -1.000000                0.000000
# 2022-11-28          30.733333             6.000000                6.083333
# 2022-11-29          30.533333             6.666667                4.750000
#
#             Sum Max Temp 72hr
# Date
# 2022-11-25           0.000000
# 2022-11-26           0.000000
# 2022-11-27         103.266667
# 2022-11-28          82.033333
# 2022-11-29          62.766667

# %%
# normalized_df=(df-df.mean())/df.std()
normalized_df=(df-df.min())/(df.max()-df.min())

# %%
training_data = normalized_df

drop = 'At Treeline'
x = training_data.drop(drop, axis=1)
y = training_data[drop]

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

rf_regressor = RandomForestRegressor(random_state=0)

rf_regressor.fit(x_train, y_train)

y_pred_train = rf_regressor.predict(x_train)
print(r2_score(y_train, y_pred_train))

y_pred = rf_regressor.predict(x_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.8522228559570102
# -0.344106274316887
